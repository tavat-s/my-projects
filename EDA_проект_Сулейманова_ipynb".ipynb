# %% [markdown]
# <a href="https://colab.research.google.com/github/tavat-s/my-projects/blob/main/EDA_%D0%BF%D1%80%D0%BE%D0%B5%D0%BA%D1%82_%D0%A1%D1%83%D0%BB%D0%B5%D0%B9%D0%BC%D0%B0%D0%BD%D0%BE%D0%B2%D0%B0_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
00
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot
import plotly.express as px

# %% [markdown]
# **Загрузим файлы, также добавим столбец с указанием 'weekday' или 'weekends'**

# %%
amsterdam_days = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/amsterdam_weekdays.csv', index_col = ['Unnamed: 0'])
amsterdam_days['weekdays/weekends'] = 'weekdays'

# %%
amsterdam_ends = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/amsterdam_weekends.csv', index_col = ['Unnamed: 0'])
amsterdam_ends['weekdays/weekends'] = 'weekends'

# %%
athens_days = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/athens_weekdays.csv', index_col = ['Unnamed: 0'])
athens_days['weekdays/weekends'] = 'weekdays'

# %%
athens_ends = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/athens_weekends.csv', index_col = ['Unnamed: 0'])
athens_ends['weekdays/weekends'] = 'weekends'

# %%
barcelona_ends = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/barcelona_weekends.csv', index_col = ['Unnamed: 0'])
barcelona_ends['weekdays/weekends'] = 'weekends'

# %%
barcelona_days = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/barcelona_weekdays.csv', index_col = ['Unnamed: 0'])
barcelona_days['weekdays/weekends'] = 'weekdays'

# %%
berlin_days = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/berlin_weekdays.csv', index_col = ['Unnamed: 0'])
berlin_ends = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/berlin_weekends.csv', index_col = ['Unnamed: 0'])
berlin_days['weekdays/weekends'] = 'weekdays'
berlin_ends['weekdays/weekends'] = 'weekends'

# %%
budapest_days = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/budapest_weekdays.csv', index_col = ['Unnamed: 0'])
budapest_ends = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/budapest_weekends.csv', index_col = ['Unnamed: 0'])
budapest_days['weekdays/weekends'] = 'weekdays'
budapest_ends['weekdays/weekends'] = 'weekends'

# %%
lisbon_days = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/lisbon_weekdays.csv', index_col = ['Unnamed: 0'])
lisbon_ends = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/lisbon_weekends.csv', index_col = ['Unnamed: 0'])
lisbon_days['weekdays/weekends'] = 'weekdays'
lisbon_ends['weekdays/weekends'] = 'weekends'

# %%
london_days = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/london_weekdays.csv', index_col = ['Unnamed: 0'])
london_ends = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/london_weekends.csv', index_col = ['Unnamed: 0'])
london_days['weekdays/weekends'] = 'weekdays'
london_ends['weekdays/weekends'] = 'weekends'

# %%
paris_days = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/paris_weekdays.csv', index_col = ['Unnamed: 0'])
paris_ends = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/paris_weekends.csv', index_col = ['Unnamed: 0'])
paris_days['weekdays/weekends'] = 'weekdays'
paris_ends['weekdays/weekends'] = 'weekends'

# %%
rome_days = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/rome_weekdays.csv', index_col = ['Unnamed: 0'])
rome_ends = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/rome_weekends.csv', index_col = ['Unnamed: 0'])
rome_days['weekdays/weekends'] = 'weekdays'
rome_ends['weekdays/weekends'] = 'weekends'

# %%
vienna_days = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/vienna_weekdays.csv', index_col = ['Unnamed: 0'])
vienna_ends = pd.read_csv('/content/gdrive/MyDrive/sql_project/Air_Bed_&_Breakfast Europe/vienna_weekends.csv', index_col = ['Unnamed: 0'])
vienna_days['weekdays/weekends'] = 'weekdays'
vienna_ends['weekdays/weekends'] = 'weekends'

# %% [markdown]
# **Посмотрим на размер каждого из файла для сравнения по городам**

# %%
print('Размер файла Амстердам будни - ' + str(amsterdam_days.shape))
print('Размер файла Амстердам выходные - ' + str(amsterdam_ends.shape))
print('Размер файла Афины будни - ' + str(athens_days.shape))
print('Размер файла Афины выходные - ' + str(athens_ends.shape))
print('Размер файла Барселона будни - ' + str(barcelona_days.shape))
print('Размер файла Барселона выходные -' + str(barcelona_ends.shape))
print('Размер файла Берлин будни -' + str(berlin_days.shape))
print('Размер файла Берлин выходные -' + str(berlin_ends.shape))
print('Размер файла Будапешт будни -' + str(budapest_days.shape))
print('Размер файла Будапешт выходные -' + str(budapest_ends.shape))
print('Размер файла Лиссабон будни -' + str(lisbon_days.shape))
print('Размер файла Лиссабон выходные -' + str(lisbon_ends.shape))
print('Размер файла Лондон будни -' + str(london_days.shape))
print('Размер файла Лондон выходные -' + str(london_ends.shape))
print('Размер файла Париж будни -' + str(paris_days.shape))
print('Размер файла Париж выходные - ' + str(paris_ends.shape))
print('Размер файла Рим будни -' + str(rome_days.shape))
print('Размер файла Рим выходные -' + str(rome_ends.shape))
print('Размер файла Венна будни - ' + str(vienna_days.shape))
print('Размер файла Венна выходные - ' + str(vienna_ends.shape))
# Out:
# Размер файла Амстердам будни - (1103, 20)
# Размер файла Амстердам выходные - (977, 20)
# Размер файла Афины будни - (2653, 20)
# Размер файла Афины выходные - (2627, 20)
# Размер файла Барселона будни - (1555, 20)
# Размер файла Барселона выходные -(1278, 20)
# Размер файла Берлин будни -(1284, 20)
# Размер файла Берлин выходные -(1200, 20)
# Размер файла Будапешт будни -(2074, 20)
# Размер файла Будапешт выходные -(1948, 20)
# Размер файла Лиссабон будни -(2857, 20)
# Размер файла Лиссабон выходные -(2906, 20)
# Размер файла Лондон будни -(4614, 20)
# Размер файла Лондон выходные -(5379, 20)
# Размер файла Париж будни -(3130, 20)
# Размер файла Париж выходные - (3558, 20)
# Размер файла Рим будни -(4492, 20)
# Размер файла Рим выходные -(4535, 20)
# Размер файла Венна будни - (1738, 20)
# Размер файла Венна выходные - (1799, 20)

# %% [markdown]
# realSum			стоимость размещения (Numeric)
# room_type		Тип комнаты или номера (private, shared, etc.). (Categorical) room_shared		Общая комната или нет (Boolean)
# room_private		Частная комната или нет (Boolean)
# person_capacity		Макимальное кол-во постояльцев (Numeric)
# host_is_superhost	Суперхост ли хозяин (Boolean)
#  multi	Несколько комнат или нет (Boolean)
#  biz			Подходит для бизнес-поездок или нет (Boolean) cleanliness_rating	Рейтинг чистоты (Numeric)
#  guest_satisfaction_overall	Общий рейтинг (Numeric)
#  bedrooms		Количество спален (Numeric) dist
# растояние от центра города (Numeric)
# metro_dist		Расстояние до ближайшей ст.метро (Numeric)
# lng			долгота (Numeric) l
# at			широта (Numeric)

# %% [markdown]
# **Объединим файлы по городам и добавим столбец 'city'**

# %%
amsterdam_all = pd.concat([amsterdam_days, amsterdam_ends], ignore_index = True)

amsterdam_all['city'] = 'amsterdam'

athens_all = pd.concat([athens_days, athens_ends], ignore_index = True)

athens_all['city'] = 'athens'

barcelona_all = pd.concat([barcelona_days, barcelona_ends], ignore_index = True)

barcelona_all['city'] = 'barcelona'

berlin_all = pd.concat([berlin_days, berlin_ends], ignore_index = True)

berlin_all['city'] = 'berlin'

budapest_all = pd.concat([budapest_days, budapest_ends], ignore_index = True)

budapest_all['city'] = 'budapest'

lisbon_all = pd.concat([lisbon_days, lisbon_ends], ignore_index = True)

lisbon_all['city'] = 'lisbon'

lisbon_all = pd.concat([lisbon_days, lisbon_ends], ignore_index = True)

lisbon_all['city'] = 'lisbon'

london_all = pd.concat([london_days, london_ends], ignore_index = True)

london_all['city'] = 'london'

paris_all = pd.concat([paris_days, paris_ends], ignore_index = True)

paris_all['city'] = 'paris'

rome_all = pd.concat([rome_days, rome_ends], ignore_index = True)

rome_all['city'] = 'rome'

vienna_all = pd.concat([vienna_days, vienna_ends], ignore_index = True)

vienna_all['city'] = 'vienna'

# %% [markdown]
# **Объединим в один датафрейм датафрейм по городам**

# %%
all_cities = pd.concat([amsterdam_all, athens_all, barcelona_all, berlin_all, budapest_all, lisbon_all, london_all, paris_all, rome_all, vienna_all], ignore_index = True)
all_cities.head(10)
# Out:
#        realSum        room_type  room_shared  room_private  person_capacity  \
# 0   194.033698     Private room        False          True              2.0
# 1   344.245776     Private room        False          True              4.0
# 2   264.101422     Private room        False          True              2.0
# 3   433.529398     Private room        False          True              4.0
# 4   485.552926     Private room        False          True              2.0
# 5   552.808567     Private room        False          True              3.0
# 6   215.124317     Private room        False          True              2.0
# 7  2771.307384  Entire home/apt        False         False              4.0
# 8  1001.804420  Entire home/apt        False         False              4.0
# 9   276.521454     Private room        False          True              2.0
#
#    host_is_superhost  multi  biz  cleanliness_rating  \
# 0              False      1    0                10.0
# ...

# %%
all_cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51707 entries, 0 to 51706
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   realSum                     51707 non-null  float64
#  1   room_type                   51707 non-null  object
#  2   room_shared                 51707 non-null  bool
#  3   room_private                51707 non-null  bool
#  4   person_capacity             51707 non-null  float64
#  5   host_is_superhost           51707 non-null  bool
#  6   multi                       51707 non-null  int64
#  7   biz                         51707 non-null  int64
#  8   cleanliness_rating          51707 non-null  float64
#  9   guest_satisfaction_overall  51707 non-null  float64
#  10  bedrooms                    51707 non-null  int64
#  11  dist                        51707 non-null  float64
#  12  metro_dist                  51707 non-null  float64
# ...

# %%
all_cities['city'].value_counts()
# Out:
# london       9993
# rome         9027
# paris        6688
# lisbon       5763
# athens       5280
# budapest     4022
# vienna       3537
# barcelona    2833
# berlin       2484
# amsterdam    2080
# Name: city, dtype: int64

# %% [markdown]
# **Построим гистограмму для оценки распределения уровня общего рейтинга и стоимости жилья**

# %%
plt.bar(all_cities["guest_satisfaction_overall"], all_cities["realSum"])

plt.xlabel("guest_satisfaction_overall")
plt.ylabel("realSum")

plt.show()

# %%
plt.bar(data["guest_satisfaction_overall"], data["realSum"])

plt.xlabel("guest_satisfaction_overall")
plt.ylabel("realSum")

plt.show()

# %% [markdown]
# **Построим плот по рейтингу чистоты и стоимость жилья**

# %%
plt.bar(all_cities["cleanliness_rating"], all_cities["realSum"])

plt.xlabel("cleanliness_rating")
plt.ylabel("realSum")

plt.show()

# %% [markdown]
# **Как видим по плоту выше ожидаемо, что "рейтинг чистоты" возрастает вместе со стоимостью жилья. Давайте посмотрим как же влияет расстояние от метро на этот же рейтинг**

# %%
plt.bar(all_cities["cleanliness_rating"], all_cities["metro_dist"])

plt.xlabel("cleanliness_rating")
plt.ylabel("metro_dist")

plt.show()

# %% [markdown]
# **Несмотря на предпочтение клиентов арендовать жильё вблизи метро, рейтинг чистоты значительно выше, если жилье не в шаговой доступности от метро и не в центре города**

# %%
plt.bar(all_cities["cleanliness_rating"], all_cities["dist"])

plt.xlabel("cleanliness_rating")
plt.ylabel("dist")

plt.show()

# %%
highest_price = all_cities.sort_values('realSum', ascending=False).head(50)

highest_price[['city','room_type','person_capacity','realSum', 'guest_satisfaction_overall','lng', 'lat']].head(10)
# Out:
#          city        room_type  person_capacity       realSum  \
# 3590   athens  Entire home/apt              2.0  18545.450285
# 34803   paris  Entire home/apt              2.0  16445.614689
# 24348  london  Entire home/apt              3.0  15499.894165
# 48380  vienna     Private room              2.0  13664.305916
# 50787  vienna     Private room              2.0  13656.358834
# 48215  vienna  Entire home/apt              4.0  12942.991375
# 30626  london  Entire home/apt              6.0  12937.275101
# 31635  london     Private room              2.0  12929.513864
# 25629  london  Entire home/apt              6.0  12886.239093
# 25945  london     Private room              2.0  12886.239093
#
#        guest_satisfaction_overall       lng       lat
# 3590                        100.0  23.73200  37.98600
# 34803                       100.0   2.29772  48.83669
# 24348                        95.0  -0.13038  51.50995
# 48380                        87.0  16.34356  48.20751
# ...

# %% [markdown]
# **Построим боксплот по городам и стоимости жилья предварительно исключив данные со стоимостью жилья выше 2500**

# %%
drop_incor = all_cities[all_cities['realSum'] > 2500].index
data = all_cities.drop(drop_incor)

# %%
plt.figure(figsize=(20,20))
sns.boxplot(x = "city", y = 'realSum', hue = "weekdays/weekends",  data = data)
plt.xticks(rotation=45, fontsize=15)
plt.show()

# %% [markdown]
# Построим плот по городам и дням недели, чтобы посмотреть по каким дням представлены данные в датасете

# %%
fig, ax = plt.subplots(figsize=(12,4))
sns.countplot(x = "city", hue = "weekdays/weekends",  data = all_cities)
plt.show()

# %% [markdown]
# Построим плот, чтобы оценить какой вместимостью и как распределяется жилье по городам

# %%
fig, ax = plt.subplots(figsize=(12,4))
sns.countplot(x='city',data=all_cities, hue='room_type')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,4))
sns.countplot(x='city',data=all_cities, hue='host_is_superhost')
plt.show()

# %% [markdown]
# Построим матрицу для определения корреляции показателей

# %%
plt.figure(figsize=(12,6))
sns.heatmap(all_cities.corr(),fmt='.2f',annot=True)
plt.show()

# %% [markdown]
# **Выделим данные по городам и дням недели посмотрим значения стоимости жилья, её средней  и границ диапазона**

# %%
all_cities.groupby(['city', 'weekdays/weekends']).realSum.describe()
# Out:
#                               count        mean         std         min  \
# city      weekdays/weekends
# amsterdam weekdays           1103.0  545.020526  416.974314  128.887118
#           weekends            977.0  604.828018  443.682821  165.912872
# athens    weekdays           2653.0  155.866982  366.573124   42.884259
#           weekends           2627.0  147.580456   79.814934   42.884259
# barcelona weekdays           1555.0  288.391667  321.180435   69.588289
#           weekends           1278.0  300.277940  393.207126   80.992390
# berlin    weekdays           1284.0  240.220422  230.318175   64.971487
#           weekends           1200.0  249.252516  240.584178   64.971487
# budapest  weekdays           2074.0  168.429367  126.059120   37.129295
#           weekends           1948.0  185.120628  135.855683   34.779339
# lisbon    weekdays           2857.0  236.345459  108.463770   70.825516
#           weekends           2906.0  240.044051  109.459172   70.590994
# ...

# %% [markdown]
# **Определим среднюю стоимости жилья по городам и дням **

# %%
all_cities.groupby(['city', 'weekdays/weekends']).realSum.mean()
# Out:
# city       weekdays/weekends
# amsterdam  weekdays             545.020526
#            weekends             604.828018
# athens     weekdays             155.866982
#            weekends             147.580456
# barcelona  weekdays             288.391667
#            weekends             300.277940
# berlin     weekdays             240.220422
#            weekends             249.252516
# budapest   weekdays             168.429367
#            weekends             185.120628
# lisbon     weekdays             236.345459
#            weekends             240.044051
# london     weekdays             360.230348
#            weekends             364.389747
# paris      weekdays             398.786678
#            weekends             387.028589
# rome       weekdays             201.618053
#            weekends             209.130063
# vienna     weekdays             240.384834
#            weekends             242.739524
# Name: realSum, dtype: float64

# %% [markdown]
# **Посмотрим как меняется средняя, если исключить из датасета данные со стоимостью жилья меньше 2500**

# %%
data.groupby(['city', 'weekdays/weekends']).realSum.mean()
# Out:
# city       weekdays/weekends
# amsterdam  weekdays             527.715366
#            weekends             585.286528
# athens     weekdays             148.932750
#            weekends             147.580456
# barcelona  weekdays             277.122739
#            weekends             279.941542
# berlin     weekdays             235.842196
#            weekends             244.576262
# budapest   weekdays             166.759203
#            weekends             183.289034
# lisbon     weekdays             236.345459
#            weekends             240.044051
# london     weekdays             338.693053
#            weekends             348.066957
# paris      weekdays             387.817893
#            weekends             381.796143
# rome       weekdays             201.618053
#            weekends             209.130063
# vienna     weekdays             225.334991
#            weekends             235.279224
# Name: realSum, dtype: float64

# %% [markdown]
# **Построим плот по расстоянию от центра и стоимости жилья до 2500**

# %%
plt.plot(data['dist'], data['realSum'], 'o', alpha=0.5, markersize=1)

plt.xlabel('dist')
plt.ylabel('realSum')
plt.title('');

# %% [markdown]
# **Построим плот по средней стоимости жилья и ругих показателей (города, тип комнаты, общий рейтинг и рейтинг чистоты жилья)**

# %%
plotter = all_cities.groupby('city')['realSum'].agg(['mean'])
plotter.columns = ["mean"]
plotter['city'] = plotter.index

data2 = [
    {
        'x': plotter['city'],
        'y': plotter['mean'],
        'mode': 'markers+text',
        'text' : plotter['city'],
        'textposition' : 'bottom center',
        'marker': {
            'size': 20,
        }
    }
]
layout = go.Layout(title="Average price for city",
                   xaxis=dict(title='city'),
                   yaxis=dict(title='realSum')
                  )
fig = go.Figure(data = data2, layout = layout)
iplot(fig, filename='scatter0')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plotter = all_cities.groupby('room_type')['realSum'].agg(['mean'])
plotter.columns = ["mean"]
plotter['room_type'] = plotter.index

data2 = [
    {
        'x': plotter['room_type'],
        'y': plotter['mean'],
        'mode': 'markers+text',
        'text' : plotter['room_type'],
        'textposition' : 'bottom center',
        'marker': {
            'size': 20,
        }
    }
]
layout = go.Layout(title="Average price for room_type",
                   xaxis=dict(title='room_type'),
                   yaxis=dict(title='realSum')
                  )
fig = go.Figure(data = data2, layout = layout)
iplot(fig, filename='scatter0')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plotter = all_cities.groupby('guest_satisfaction_overall')['realSum'].agg(['mean'])
plotter.columns = ["mean"]
plotter['guest_satisfaction_overall'] = plotter.index

data2 = [
    {
        'x': plotter['guest_satisfaction_overall'],
        'y': plotter['mean'],
        'mode': 'markers+text',
        'text' : plotter['guest_satisfaction_overall'],
        'textposition' : 'bottom center',
        'marker': {
            'size': 20,
        }
    }
]
layout = go.Layout(title="Average price for guest_satisfaction_overall",
                   xaxis=dict(title='guest_satisfaction_overall'),
                   yaxis=dict(title='realSum')
                  )
fig = go.Figure(data = data2, layout = layout)
iplot(fig, filename='scatter0')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plotter = all_cities.groupby('cleanliness_rating')['realSum'].agg(['mean'])
plotter.columns = ["mean"]
plotter['cleanliness_rating'] = plotter.index

data2 = [
    {
        'x': plotter['cleanliness_rating'],
        'y': plotter['mean'],
        'mode': 'markers+text',
        'text' : plotter['cleanliness_rating'],
        'textposition' : 'bottom center',
        'marker': {
            'size': 20,
        }
    }
]
layout = go.Layout(title="Average price for cleanliness_rating",
                   xaxis=dict(title='cleanliness_rating'),
                   yaxis=dict(title='realSum')
                  )
fig = go.Figure(data = data2, layout = layout)
iplot(fig, filename='scatter0')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Заключение**
#
# ---
#
# - Несмотря на то, что рейтинг чистоты и общий рейтинг возрастают с увеличением цены, по наиболее высоким средним стоимости жилья, рейтинг чистоты находится в границах от 2 до 7 и не привышает 280 евро. Средняя стоимость жилья по общему рейтингу выше 80 находится в ддиапазоне от 230 до 316 евро
# - Средняя стоимость entire apart значительно выше стоимости private room и shared room
# - Наиболее дорогое жилье находмися в Амстердаме, Лондоне и Париже
# - Чем дальше от метро и центра города расположено жилье, тем выше рейтинг чистоты
